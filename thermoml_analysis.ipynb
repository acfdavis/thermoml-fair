# %% [markdown]
# # ThermoML Data Analysis
#
# This notebook demonstrates how to use the `thermoml-fair` package to load, process, and analyze data from ThermoML archives.
#
# We will perform the following steps:
# 1.  Generate standardized data files (CSVs) from the raw ThermoML XML files.
# 2.  Load the data into pandas DataFrames.
# 3.  Explore the structure of the data.
# 4.  Filter the data to find specific properties, focusing on **thermal conductivity of crystalline solids**.
# 5.  Visualize the results.

# %%
# First, ensure the required packages are installed
import sys
# !{sys.executable} -m pip install pandas plotly
# Out:
# Requirement already satisfied: pandas in c:\users\angel\.ai-navigator\micromamba\envs\cpu\lib\site-packages (2.2.3)
# Requirement already satisfied: plotly in c:\users\angel\.ai-navigator\micromamba\envs\cpu\lib\site-packages (6.1.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\angel\.ai-navigator\micromamba\envs\cpu\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\angel\.ai-navigator\micromamba\envs\cpu\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\angel\.ai-navigator\micromamba\envs\cpu\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\angel\.ai-navigator\micromamba\envs\cpu\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\angel\.ai-navigator\micromamba\envs\cpu\lib\site-packages (from plotly) (1.41.0)
# Requirement already satisfied: packaging in c:\users\angel\.ai-navigator\micromamba\envs\cpu\lib\site-packages (from plotly) (25.0)
# Requirement already satisfied: six>=1.5 in c:\users\angel\.ai-navigator\micromamba\envs\cpu\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# Step 1: Generate the data files using the thermoml-fair CLI
# This command processes the XML files and creates CSVs for easier analysis.
# It'''s equivalent to running `thermoml-fair build-dataframe` in your terminal.
# This parses over 10,000 ThermoML XML files, which can take some time depending on your system's performance.
# !thermoml-fair build-dataframe --output-data-file thermoml_data.csv --output-compounds-file thermoml_compounds.csv
# Out:
# ^C
# No input directory specified, using default: C:\Users\angel\.thermoml\extracted_xml
# Building DataFrames from data in: C:\Users\angel\.thermoml\extracted_xml
# Found 11923 XML file(s) and 11624 .parsed.pkl file(s) in C:\Users\angel\.thermoml\extracted_xml.
# The process will prioritize .parsed.pkl files.
# Starting DataFrame construction process... This may take a while depending on data size and if parsing is needed.
#
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:00
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:00
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:00
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:00
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:00
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:00
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:01
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:01
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:01
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:02
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:02
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:02
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:02
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:02
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:02
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:02
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:02
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:03
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:03
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:03
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:03
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:03
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:03
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:03
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:03
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:04
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:04
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:04
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:04
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:04
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:04
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:04
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:04
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:04
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:05
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:05
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:05
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:05
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:05
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:05
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:05
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:05
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:06
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:06
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:06
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:06
# Parsing XML files... ------------------------   0% (1 of 11923) -:--:-- 0:00:06
# Parsing XML files... ------------------------   0% (1 of 11923) -:--:-- 0:00:06
# Parsing XML files... ------------------------   0% (1 of 11923) -:--:-- 0:00:06
# Parsing XML files... ------------------------   0% (2 of 11923) 1:37:26 0:00:06
# Parsing XML files... ------------------------   0% (2 of 11923) 1:37:26 0:00:07
# Parsing XML files... ------------------------   0% (2 of 11923) 1:37:26 0:00:07
# Parsing XML files... ------------------------   0% (6 of 11923) 0:37:55 0:00:07
# Parsing XML files... ------------------------   0% (6 of 11923) 0:37:55 0:00:07
# Parsing XML files... ------------------------   0% (6 of 11923) 0:37:55 0:00:07
# Parsing XML files... ------------------------   0% (6 of 11923) 0:37:55 0:00:07
# Parsing XML files... -----------------------   0% (10 of 11923) 0:42:08 0:00:08
# Parsing XML files... -----------------------   0% (13 of 11923) 0:39:27 0:00:08
# Parsing XML files... -----------------------   0% (17 of 11923) 0:36:40 0:00:09
# Parsing XML files... -----------------------   0% (21 of 11923) 0:32:38 0:00:09
# Parsing XML files... -----------------------   0% (26 of 11923) 0:28:44 0:00:10
# Parsing XML files... -----------------------   0% (30 of 11923) 0:27:17 0:00:10
# Parsing XML files... -----------------------   0% (37 of 11923) 0:23:47 0:00:10
# Parsing XML files... -----------------------   0% (40 of 11923) 0:22:49 0:00:10
# Parsing XML files... -----------------------   0% (45 of 11923) 0:21:40 0:00:11
# Parsing XML files... -----------------------   0% (47 of 11923) 0:21:22 0:00:11
# Parsing XML files... -----------------------   0% (52 of 11923) 0:21:12 0:00:11
# Parsing XML files... -----------------------   0% (54 of 11923) 0:21:09 0:00:12
# Parsing XML files... -----------------------   0% (58 of 11923) 0:20:48 0:00:12
# Parsing XML files... -----------------------   1% (62 of 11923) 0:20:24 0:00:12
# Parsing XML files... -----------------------   1% (64 of 11923) 0:20:19 0:00:12
# Parsing XML files... -----------------------   1% (68 of 11923) 0:19:57 0:00:13
# Parsing XML files... -----------------------   1% (71 of 11923) 0:19:45 0:00:13
# Parsing XML files... -----------------------   1% (75 of 11923) 0:19:47 0:00:13
# Parsing XML files... -----------------------   1% (78 of 11923) 0:19:35 0:00:14
# Parsing XML files... -----------------------   1% (82 of 11923) 0:19:29 0:00:14
# Parsing XML files... -----------------------   1% (87 of 11923) 0:19:58 0:00:15
# Parsing XML files... -----------------------   1% (90 of 11923) 0:19:47 0:00:15
# Parsing XML files... -----------------------   1% (94 of 11923) 0:19:30 0:00:15
# Parsing XML files... -----------------------   1% (98 of 11923) 0:19:22 0:00:16
# Parsing XML files... ----------------------   1% (101 of 11923) 0:19:14 0:00:16
# Parsing XML files... ----------------------   1% (104 of 11923) 0:19:02 0:00:16
# Parsing XML files... ----------------------   1% (106 of 11923) 0:19:02 0:00:16
# Parsing XML files... ----------------------   1% (109 of 11923) 0:18:55 0:00:16
# Parsing XML files... ----------------------   1% (114 of 11923) 0:18:44 0:00:17
# Parsing XML files... ----------------------   1% (117 of 11923) 0:18:48 0:00:17
# Parsing XML files... ----------------------   1% (121 of 11923) 0:18:43 0:00:17
# Parsing XML files... ----------------------   1% (125 of 11923) 0:19:23 0:00:18
# Parsing XML files... ----------------------   1% (130 of 11923) 0:19:07 0:00:19
# Parsing XML files... ----------------------   1% (134 of 11923) 0:19:10 0:00:19
# Parsing XML files... ----------------------   1% (139 of 11923) 0:19:09 0:00:19
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:20
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:20
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:20
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:21
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:21
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:21
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:22
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:22
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:22
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:22
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:23
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:23
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:23
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:23
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:23
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:24
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:24
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:24
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:25
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:25
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:26
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:26
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:26
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:27
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:27
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:27
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:27
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:28
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:28
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:28
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:29
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:29
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:29
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:29
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:30
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:30
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:31
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:31
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:31
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:31
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:32
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:32
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:32
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:32
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:33
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:33
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:33
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:34
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:34
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:34
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:35
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:35
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:35
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:36
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:36
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:36
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:36
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:37
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:37
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:37
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:38
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:38
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:38
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:38
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:39
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:39
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:39
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:39
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:40
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:40
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:40
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:40
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:41
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:41
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:42
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:42
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:42
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:43
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:43
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:43
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:43
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:44
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:44
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:44
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:44
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:45
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:45
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:45
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:45
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:46
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:46
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:46
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:46
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:47
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:47
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:48
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:48
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:49
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:49
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:49
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:49
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:50
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:50
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:50
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:51
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:51
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:51
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:51
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:52
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:52
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:52
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:53
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:53
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:53
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:54
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:54
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:55
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:55
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:55
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:56
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:56
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:56
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:57
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:58
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:58
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:58
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:59
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:59
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:00:59
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:00
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:00
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:01
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:01
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:01
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:01
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:02
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:02
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:02
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:02
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:02
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:03
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:03
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:03
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:04
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:04
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:04
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:04
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:05
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:05
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:05
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:06
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:06
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:06
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:07
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:07
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:07
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:08
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:08
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:08
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:08
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:08
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:09
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:09
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:09
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:10
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:10
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:10
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:10
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:11
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:11
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:11
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:11
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:12
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:12
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:12
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:12
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:12
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:12
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:13
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:13
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:13
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:14
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:14
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:14
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:14
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:14
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:15
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:15
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:15
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:17
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:17
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:17
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:17
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:17
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:18
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:18
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:18
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:18
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:18
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:19
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:19
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:19
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:19
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:20
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:20
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:20
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:21
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:21
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:21
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:21
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:21
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:22
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:22
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:22
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:22
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:23
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:23
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:23
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:24
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:24
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:24
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:24
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:25
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:25
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:25
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:25
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:26
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:26
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:26
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:26
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:27
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:27
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:27
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:27
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:28
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:29
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:29
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:29
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:29
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:29
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:30
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:30
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:30
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:30
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:31
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:31
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:31
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:31
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:32
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:32
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:32
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:32
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:33
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:33
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:33
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:34
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:34
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:34
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:34
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:35
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:35
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:35
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:35
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:36
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:36
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:36
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:36
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:37
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:37
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:37
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:37
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:38
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:38
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:38
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:38
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:39
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:39
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:39
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:39
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:39
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:40
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:40
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:40
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:41
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:41
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:41
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:41
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:42
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:43
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:43
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:43
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:43
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:44
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:44
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:44
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:44
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:45
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:45
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:45
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:45
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:46
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:46
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:46
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:46
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:47
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:47
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:47
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:47
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:47
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:48
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:48
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:48
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:48
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:49
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:49
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:49
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:49
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:49
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:50
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:50
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:50
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:50
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:51
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:51
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:51
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:51
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:52
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:52
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:53
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:53
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:53
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:54
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:54
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:54
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:55
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:55
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:56
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:56
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:56
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:57
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:57
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:57
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:57
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:57
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:58
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:59
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:01:59
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:00
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:00
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:00
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:01
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:01
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:01
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:02
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:02
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:02
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:02
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:03
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:03
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:03
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:04
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:04
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:04
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:05
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:05
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:05
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:05
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:06
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:06
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:06
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:07
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:07
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:08
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:08
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:09
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:09
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:10
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:10
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:10
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:11
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:11
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:11
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:12
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:12
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:12
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:13
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:13
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:13
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:13
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:14
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:14
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:15
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:15
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:15
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:16
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:16
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:16
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:17
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:17
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:17
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:17
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:18
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:18
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:18
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:18
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:19
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:19
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:20
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:20
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:20
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:20
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:21
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:21
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:23
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:23
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:23
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:23
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:24
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:24
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:24
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:24
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:24
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:25
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:25
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:25
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:25
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:26
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:26
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:26
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:26
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:26
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:27
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:27
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:27
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:27
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:28
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:28
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:28
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:28
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:28
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:29
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:29
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:29
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:29
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:30
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:30
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:30
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:31
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:31
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:31
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:32
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:32
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:32
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:32
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:33
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:33
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:33
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:34
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:34
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:34
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:34
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:34
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:35
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:35
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:35
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:35
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:35
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:36
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:36
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:36
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:36
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:37
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:37
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:37
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:38
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:38
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:38
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:38
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:39
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:39
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:39
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:39
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:40
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:40
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:40
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:41
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:41
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:41
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:42
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:42
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:44
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:44
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:45
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:45
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:45
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:46
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:46
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:46
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:46
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:47
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:47
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:47
# Parsing XML files... ----------------------   1% (141 of 11923) 0:19:06 0:02:47
# ...
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je049823k.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je049823k.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je049878m.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je049878m.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je050502y.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je050502y.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je0600303.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je0600303.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je0600698.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je0600698.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je060268r.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je060268r.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je100142g.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je100142g.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je100208e.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je100208e.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je100526j.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je100526j.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je100606z.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je100606z.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je100749m.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je100749m.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je101058b.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je101058b.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je101215x.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je101215x.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je200468r.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je200468r.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je200506p.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je200506p.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je200681k.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je200681k.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je200800f.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je200800f.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je200869q.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je200869q.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je200950f.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je200950f.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je201193d.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je201193d.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je300170y.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je300170y.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je3009792.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je3009792.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je400951k.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je400951k.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je500110d.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je500110d.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je5001389.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je5001389.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je500684w.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je500684w.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je500845d.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je500845d.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je700204d.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je700204d.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je700381u.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je700381u.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je700595y.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je700595y.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je8002207.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je8002207.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je800285k.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je800285k.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je800606r.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je800606r.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je800628a.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je800628a.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je800747v.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je800747v.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je800789b.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je800789b.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je800848u.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je800848u.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je900124n.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je900124n.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je900292r.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je900292r.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je900342a.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je900342a.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je900355h.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je900355h.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je9003614.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je9003614.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je900410j.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je900410j.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je9008206.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je9008206.xml is not valid against the provided ThermoML schema.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1021\je900902z.xml with schema XMLSchema10(name='ThermoML.xsd', namespace='http://www.iupac.org/namespaces/ThermoML'): C:\Users\angel\.thermoml\extracted_xml\10.1021\je900902z.xml is not valid against the provided ThermoML schema.
# [ERROR] An error occurred during DataFrame construction: C:\Users\angel\.thermoml\extracted_xml\10.1007\s10765-013-1404-4.xml is not valid against the provided ThermoML schema.
# concurrent.futures.process._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\angel\.ai-navigator\micromamba\envs\cpu\Lib\concurrent\futures\process.py", line 254, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#   File "C:\Users\angel\.ai-navigator\micromamba\envs\cpu\Lib\site-packages\thermoml_fair\core\utils.py", line 72, in parse_one
#     raise e
#   File "C:\Users\angel\.ai-navigator\micromamba\envs\cpu\Lib\site-packages\thermoml_fair\core\utils.py", line 66, in parse_one
#     return parse_thermoml_xml(file_path, xsd_path_or_obj=schema_for_parsing)
#   File "C:\Users\angel\.ai-navigator\micromamba\envs\cpu\Lib\site-packages\thermoml_fair\core\parser.py", line 62, in parse_thermoml_xml
#     raise ValueError(f"{file_path} is not valid against the provided ThermoML schema.")
# ValueError: C:\Users\angel\.thermoml\extracted_xml\10.1007\s10765-013-1404-4.xml is not valid against the provided ThermoML schema.
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\angel\.ai-navigator\micromamba\envs\cpu\Lib\site-packages\thermoml_fair\scripts\cli.py", line 449, in build_dataframe
#     data_bundle = build_pandas_dataframe(
#         xml_files=[str(f) for f in xml_files_in_input_dir], # Pass XMLs to guide it; .pkl files are expected to be co-located or found by the function based on these paths
#     ...<3 lines>...
#         max_workers=max_workers
#     )
#   File "C:\Users\angel\.ai-navigator\micromamba\envs\cpu\Lib\site-packages\thermoml_fair\core\utils.py", line 137, in build_pandas_dataframe
#     parsed_records, parsed_compounds = future.result()
#                                        ~~~~~~~~~~~~~^^
#   File "C:\Users\angel\.ai-navigator\micromamba\envs\cpu\Lib\concurrent\futures\_base.py", line 449, in result
#     return self.__get_result()
#            ~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\angel\.ai-navigator\micromamba\envs\cpu\Lib\concurrent\futures\_base.py", line 401, in __get_result
#     raise self._exception
# ValueError: C:\Users\angel\.thermoml\extracted_xml\10.1007\s10765-013-1404-4.xml is not valid against the provided ThermoML schema.

# %%
# Step 2: Load the generated data into pandas DataFrames
import pandas as pd
import os

data_file = 'thermoml_data.csv'
compounds_file = 'thermoml_compounds.csv'

if os.path.exists(data_file) and os.path.exists(compounds_file):
    df_data = pd.read_csv(data_file)
    df_compounds = pd.read_csv(compounds_file)
    print("DataFrames loaded successfully.")
else:
    print("Error: Data files not found. Make sure the previous cell ran successfully.")
# Out:
# DataFrames loaded successfully.

# %%
# Step 3: Explore the data
# Let'''s look at the first few rows and the columns of the main data file.
if 'df_data' in locals():
    print("Columns in the main data file:")
    print(df_data.columns)
    print("\nFirst 5 rows of the main data:")
    display(df_data.head())
# Out:
# Columns in the main data file:
# Index(['material_id', 'components', 'thermoml_fair_version', 'property',
#        'value', 'phase', 'method', 'uncertainty', 'source_file', 'doi',
#        'publication_year', 'title', 'author', 'journal'],
#       dtype='object')
#
# First 5 rows of the main data:
#   material_id      components thermoml_fair_version  \
# 0           1  1,2-ethanediol                1.0.12
# 1           1  1,2-ethanediol                1.0.12
# 2           1  1,2-ethanediol                1.0.12
# 3           1  1,2-ethanediol                1.0.12
# 4           1  1,2-ethanediol                1.0.12
#
#                       property   value   phase           method  uncertainty  \
# 0  Thermal conductivity, W/m/K  0.2496  Liquid  Hot disk method          NaN
# 1  Thermal conductivity, W/m/K  0.2518  Liquid  Hot disk method          NaN
# 2  Thermal conductivity, W/m/K  0.2539  Liquid  Hot disk method          NaN
# 3  Thermal conductivity, W/m/K  0.2561  Liquid  Hot disk method          NaN
# 4  Thermal conductivity, W/m/K  0.2580  Liquid  Hot disk method          NaN
#
#                                          source_file  \
# 0  C:\Users\angel\.thermoml\extracted_xml\10.1007...
# 1  C:\Users\angel\.thermoml\extracted_xml\10.1007...
# 2  C:\Users\angel\.thermoml\extracted_xml\10.1007...
# 3  C:\Users\angel\.thermoml\extracted_xml\10.1007...
# 4  C:\Users\angel\.thermoml\extracted_xml\10.1007...
#
#                          doi  publication_year  \
# 0  10.1007/s10765-005-5568-4              2005
# 1  10.1007/s10765-005-5568-4              2005
# 2  10.1007/s10765-005-5568-4              2005
# 3  10.1007/s10765-005-5568-4              2005
# 4  10.1007/s10765-005-5568-4              2005
#
#                                                title      author  \
# 0  Application of the Multi-Current Transient Hot...  Khayet, M.
# 1  Application of the Multi-Current Transient Hot...  Khayet, M.
# 2  Application of the Multi-Current Transient Hot...  Khayet, M.
# 3  Application of the Multi-Current Transient Hot...  Khayet, M.
# 4  Application of the Multi-Current Transient Hot...  Khayet, M.
#
#                journal
# 0  Int. J. Thermophys.
# 1  Int. J. Thermophys.
# 2  Int. J. Thermophys.
# 3  Int. J. Thermophys.
# 4  Int. J. Thermophys.

# %%
# Step 4: Filter for Thermal Conductivity of Crystalline Solids

# Thank you for providing the CSV header. It clarifies the data structure.
# The data is in a simple "long" format, so no complex pivoting is needed.
# My previous attempts were based on an incorrect assumption about the column names.

# Let'''s use the correct column names from your file to filter the data.

if 'df_data' in locals():
    # The correct column names from your CSV are:
    property_col = 'property'
    phase_col = 'phase'
    value_col = 'value'

    # Check if these columns exist
    if property_col in df_data.columns and phase_col in df_data.columns:
        
        # 1. Filter for rows where the property is 'Thermal conductivity'
        # We use .str.contains() for a case-insensitive search.
        conductivity_df = df_data[df_data[property_col].str.contains('Thermal conductivity', case=False, na=False)].copy()

        # 2. From those results, filter for crystalline phases
        crystalline_df = conductivity_df[conductivity_df[phase_col].str.contains('crystal', case=False, na=False)]

        print(f"Found {len(crystalline_df)} records for thermal conductivity in crystalline phases.")
        
        # Display the filtered data
        if not crystalline_df.empty:
            print("Displaying filtered results:")
            display(crystalline_df.head())
        else:
            print("No matching records found after filtering.")

    else:
        print(f"Error: The required columns ('{property_col}' and/or '{phase_col}') were not found in the DataFrame.")
        print("Please check the column list from cell 5.")
# Out:
# Found 318 records for thermal conductivity in crystalline phases.
# Displaying filtered results:
#       material_id components thermoml_fair_version  \
# 40565           1       iron                1.0.12
# 40566           1       iron                1.0.12
# 40567           1       iron                1.0.12
# 40568           1       iron                1.0.12
# 40569           1       iron                1.0.12
#
#                           property  value      phase method  uncertainty  \
# 40565  Thermal conductivity, W/m/K   82.5  Crystal 4    NaN          NaN
# 40566  Thermal conductivity, W/m/K   73.4  Crystal 4    NaN          NaN
# 40567  Thermal conductivity, W/m/K   65.5  Crystal 4    NaN          NaN
# 40568  Thermal conductivity, W/m/K   58.2  Crystal 4    NaN          NaN
# 40569  Thermal conductivity, W/m/K   52.0  Crystal 4    NaN          NaN
#
#                                              source_file  \
# 40565  C:\Users\angel\.thermoml\extracted_xml\10.1007...
# 40566  C:\Users\angel\.thermoml\extracted_xml\10.1007...
# 40567  C:\Users\angel\.thermoml\extracted_xml\10.1007...
# 40568  C:\Users\angel\.thermoml\extracted_xml\10.1007...
# 40569  C:\Users\angel\.thermoml\extracted_xml\10.1007...
#
#                              doi  publication_year  \
# 40565  10.1007/s10765-019-2568-3              2019
# 40566  10.1007/s10765-019-2568-3              2019
# 40567  10.1007/s10765-019-2568-3              2019
# 40568  10.1007/s10765-019-2568-3              2019
# 40569  10.1007/s10765-019-2568-3              2019
#
#                                                    title  \
# 40565  Intercomparison of Thermophysical Property Mea...
# 40566  Intercomparison of Thermophysical Property Mea...
# 40567  Intercomparison of Thermophysical Property Mea...
# 40568  Intercomparison of Thermophysical Property Mea...
# 40569  Intercomparison of Thermophysical Property Mea...
#
#                          author              journal
# 40565  Ebert, H.-P.[Hans-Peter]  Int. J. Thermophys.
# 40566  Ebert, H.-P.[Hans-Peter]  Int. J. Thermophys.
# 40567  Ebert, H.-P.[Hans-Peter]  Int. J. Thermophys.
# 40568  Ebert, H.-P.[Hans-Peter]  Int. J. Thermophys.
# 40569  Ebert, H.-P.[Hans-Peter]  Int. J. Thermophys.
