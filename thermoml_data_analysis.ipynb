# %%
# ThermoML Data Analysis Workflow

This notebook demonstrates two methods for extracting and analyzing ThermoML data using the `thermoml-fair` package.

There are two primary ways to accomplish this:
1.  **Using the Command-Line Interface (CLI)**: A straightforward method for generating CSV files directly.
2.  **Calling the Python Function Directly**: A more flexible approach that loads data directly into pandas DataFrames in your notebook for immediate analysis.

---

# %% [markdown]
# ## Method 1: Using the Command-Line Interface (CLI)
#
# This method is recommended for its simplicity and robustness. The CLI tool processes all XML files in a directory, skips any that fail, and reports the failed files. This ensures you always get a CSV file with all the data that could be successfully parsed.

# %%
# The `build-dataframe` command is the primary entry point for the CLI.
# It scans a directory for ThermoML files (.xml or cached .pkl), processes them,
# and saves the extracted data into three separate CSV files.
# We use --input-dir to specify the location of our data.
# The --show-failed-files flag provides a summary of any files that couldn't be processed.
# !thermoml-fair build-dataframe
# Out:
# No input directory specified, using default: C:\Users\angel\.thermoml\extracted_xml
# Building DataFrames from data in: C:\Users\angel\.thermoml\extracted_xml
# Found 11923 XML file(s) and 11624 .parsed.pkl file(s) in C:\Users\angel\.thermoml\extracted_xml.
# The process will prioritize .parsed.pkl files.
# Starting DataFrame construction process... This may take a while depending on data size and if parsing is needed.
#
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:00
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:00
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:00
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:00
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:00
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:00
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:00
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:00
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:01
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:01
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:01
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:01
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:01
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:01
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:01
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:01
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:02
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:02
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:02
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:02
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:02
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:02
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:02
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:02
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:03
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:03
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:03
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:03
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:03
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:03
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:03
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:03
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:03
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:04
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:04
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:04
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:04
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:04
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:04
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:04
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:04
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:04
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:05
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:05
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:05
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:05
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:05
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:05
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:05
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:05
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:06
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:06
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:06
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:06
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:06
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:06
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:06
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:06
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:06
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:07
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:07
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:07
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:07
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:07
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:07
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:07
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:07
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:07
# Parsing XML files... ------------------------   0% (0 of 11923) -:--:-- 0:00:08
# Parsing XML files... ------------------------   0% (2 of 11923) 0:10:40 0:00:08
# Parsing XML files... ------------------------   0% (4 of 11923) 0:11:32 0:00:08
# Parsing XML files... ------------------------   0% (7 of 11923) 0:09:46 0:00:08
# Parsing XML files... ------------------------   0% (8 of 11923) 0:11:00 0:00:08
# Parsing XML files... ------------------------   0% (9 of 11923) 0:11:34 0:00:08
# Parsing XML files... ------------------------   0% (9 of 11923) 0:11:34 0:00:08
# Parsing XML files... ------------------------   0% (9 of 11923) 0:11:34 0:00:08
# Parsing XML files... -----------------------   0% (10 of 11923) 0:18:07 0:00:09
# Parsing XML files... -----------------------   0% (13 of 11923) 0:16:25 0:00:09
# Parsing XML files... -----------------------   0% (16 of 11923) 0:14:46 0:00:09
# Parsing XML files... -----------------------   0% (21 of 11923) 0:12:37 0:00:09
# Parsing XML files... -----------------------   0% (22 of 11923) 0:12:29 0:00:09
# Parsing XML files... -----------------------   0% (29 of 11923) 0:10:31 0:00:09
# Parsing XML files... -----------------------   0% (34 of 11923) 0:09:21 0:00:09
# Parsing XML files... -----------------------   0% (38 of 11923) 0:09:06 0:00:09
# Parsing XML files... -----------------------   0% (42 of 11923) 0:08:46 0:00:09
# Parsing XML files... -----------------------   0% (48 of 11923) 0:08:11 0:00:10
# Parsing XML files... -----------------------   1% (64 of 11923) 0:06:56 0:00:10
# Parsing XML files... ----------------------   1% (104 of 11923) 0:04:39 0:00:10
# Parsing XML files... ----------------------   1% (125 of 11923) 0:04:07 0:00:10
# Parsing XML files... ----------------------   1% (158 of 11923) 0:03:30 0:00:10
# Parsing XML files... ----------------------   1% (177 of 11923) 0:03:16 0:00:11
# Parsing XML files... ----------------------   2% (203 of 11923) 0:02:56 0:00:11
# Parsing XML files... ----------------------   2% (250 of 11923) 0:02:36 0:00:11
# Parsing XML files... ----------------------   2% (266 of 11923) 0:02:33 0:00:11
# Parsing XML files...  ---------------------   2% (279 of 11923) 0:02:30 0:00:11
# Parsing XML files...  ---------------------   3% (333 of 11923) 0:02:26 0:00:12
# Parsing XML files...  ---------------------   3% (347 of 11923) 0:02:23 0:00:12
# Parsing XML files...  ---------------------   3% (363 of 11923) 0:02:21 0:00:12
# Parsing XML files...  ---------------------   3% (379 of 11923) 0:02:19 0:00:12
# Parsing XML files...  ---------------------   3% (401 of 11923) 0:02:14 0:00:12
# Parsing XML files...  ---------------------   4% (423 of 11923) 0:02:10 0:00:12
# Parsing XML files...  ---------------------   4% (465 of 11923) 0:02:04 0:00:13
# Parsing XML files...  ---------------------   4% (484 of 11923) 0:02:03 0:00:13
# Parsing XML files...  ---------------------   4% (504 of 11923) 0:02:01 0:00:13
# Parsing XML files... - --------------------   5% (589 of 11923) 0:01:59 0:00:14
# Parsing XML files... - --------------------   5% (603 of 11923) 0:01:59 0:00:14
# Parsing XML files... - --------------------   5% (628 of 11923) 0:01:57 0:00:14
# Parsing XML files... - --------------------   6% (659 of 11923) 0:01:54 0:00:14
# Parsing XML files... - --------------------   6% (676 of 11923) 0:01:53 0:00:14
# Parsing XML files... - --------------------   6% (690 of 11923) 0:01:52 0:00:14
# Parsing XML files... - --------------------   6% (729 of 11923) 0:01:48 0:00:15
# Parsing XML files... - --------------------   6% (764 of 11923) 0:01:53 0:00:15
# Parsing XML files... - --------------------   7% (824 of 11923) 0:01:49 0:00:16
# Parsing XML files... - --------------------   7% (857 of 11923) 0:01:46 0:00:16
# Parsing XML files... - --------------------   7% (886 of 11923) 0:01:44 0:00:16
# Parsing XML files... - --------------------   8% (903 of 11923) 0:01:43 0:00:16
# Parsing XML files... - --------------------   8% (922 of 11923) 0:01:43 0:00:16
# Parsing XML files... - --------------------   8% (945 of 11923) 0:01:41 0:00:16
# Parsing XML files... - --------------------   8% (982 of 11923) 0:01:39 0:00:16
# Parsing XML files... - --------------------   8% (984 of 11923) 0:01:39 0:00:17
# Parsing XML files... - -------------------   8% (1010 of 11923) 0:01:36 0:00:17
# Parsing XML files... - -------------------   9% (1059 of 11923) 0:01:25 0:00:18
# Parsing XML files... - -------------------   9% (1110 of 11923) 0:01:23 0:00:18
# Parsing XML files... -- ------------------  10% (1147 of 11923) 0:01:22 0:00:18
# Parsing XML files... -- ------------------  10% (1173 of 11923) 0:01:21 0:00:18
# Parsing XML files... -- ------------------  10% (1206 of 11923) 0:01:21 0:00:18
# Parsing XML files... -- ------------------  10% (1232 of 11923) 0:01:20 0:00:18
# Parsing XML files... -- ------------------  11% (1268 of 11923) 0:01:18 0:00:18
# Parsing XML files... -- ------------------  11% (1318 of 11923) 0:01:14 0:00:19
# Parsing XML files... -- ------------------  11% (1324 of 11923) 0:01:13 0:00:19
# Parsing XML files... -- ------------------  12% (1407 of 11923) 0:01:19 0:00:20
# Parsing XML files... -- ------------------  12% (1442 of 11923) 0:01:18 0:00:20
# Parsing XML files... -- ------------------  12% (1471 of 11923) 0:01:18 0:00:20
# Parsing XML files... -- ------------------  13% (1501 of 11923) 0:01:17 0:00:20
# Parsing XML files... -- ------------------  13% (1523 of 11923) 0:01:13 0:00:20
# Parsing XML files... -- ------------------  13% (1556 of 11923) 0:01:12 0:00:21
# Parsing XML files... -- ------------------  13% (1575 of 11923) 0:01:12 0:00:21
# Parsing XML files... -- ------------------  13% (1605 of 11923) 0:01:11 0:00:21
# Parsing XML files... -- ------------------  14% (1636 of 11923) 0:01:10 0:00:21
# Parsing XML files... -- ------------------  14% (1664 of 11923) 0:01:10 0:00:21
# Parsing XML files... -- ------------------  14% (1688 of 11923) 0:01:10 0:00:21
# Parsing XML files... --- -----------------  14% (1712 of 11923) 0:01:10 0:00:21
# Parsing XML files... --- -----------------  14% (1713 of 11923) 0:01:10 0:00:22
# Parsing XML files... --- -----------------  15% (1729 of 11923) 0:01:15 0:00:23
# Parsing XML files... --- -----------------  15% (1757 of 11923) 0:01:15 0:00:23
# Parsing XML files... --- -----------------  15% (1795 of 11923) 0:01:14 0:00:23
# Parsing XML files... --- -----------------  15% (1825 of 11923) 0:01:14 0:00:23
# Parsing XML files... --- -----------------  16% (1864 of 11923) 0:01:13 0:00:23
# Parsing XML files... --- -----------------  16% (1908 of 11923) 0:01:12 0:00:23
# Parsing XML files... --- -----------------  16% (1934 of 11923) 0:01:12 0:00:23
# Parsing XML files... --- -----------------  16% (1967 of 11923) 0:01:11 0:00:23
# Parsing XML files... --- -----------------  17% (1989 of 11923) 0:01:04 0:00:24
# Parsing XML files... --- -----------------  17% (2018 of 11923) 0:01:04 0:00:24
# Parsing XML files... --- -----------------  17% (2033 of 11923) 0:01:04 0:00:24
# Parsing XML files... --- -----------------  17% (2061 of 11923) 0:01:04 0:00:24
# Parsing XML files... --- -----------------  17% (2083 of 11923) 0:01:05 0:00:24
# Parsing XML files... --- -----------------  18% (2109 of 11923) 0:01:05 0:00:24
# Parsing XML files... --- -----------------  18% (2136 of 11923) 0:01:05 0:00:24
# Parsing XML files... --- -----------------  18% (2155 of 11923) 0:01:04 0:00:26
# Parsing XML files... --- -----------------  18% (2177 of 11923) 0:01:19 0:00:26
# Parsing XML files... --- -----------------  19% (2212 of 11923) 0:01:19 0:00:26
# Parsing XML files... --- -----------------  19% (2244 of 11923) 0:01:19 0:00:26
# Parsing XML files... ---- ----------------  19% (2273 of 11923) 0:01:19 0:00:27
# Parsing XML files... ---- ----------------  19% (2289 of 11923) 0:01:20 0:00:27
# Parsing XML files... ---- ----------------  19% (2311 of 11923) 0:01:20 0:00:27
# Parsing XML files... ---- ----------------  20% (2330 of 11923) 0:01:13 0:00:27
# Parsing XML files... ---- ----------------  20% (2356 of 11923) 0:01:12 0:00:27
# Parsing XML files... ---- ----------------  20% (2369 of 11923) 0:01:13 0:00:27
# Parsing XML files... ---- ----------------  20% (2390 of 11923) 0:01:13 0:00:27
# Parsing XML files... ---- ----------------  20% (2425 of 11923) 0:01:13 0:00:28
# Parsing XML files... ---- ----------------  20% (2443 of 11923) 0:01:14 0:00:28
# Parsing XML files... ---- ----------------  21% (2459 of 11923) 0:01:14 0:00:28
# Parsing XML files... ---- ----------------  21% (2485 of 11923) 0:01:13 0:00:28
# Parsing XML files... ---- ----------------  21% (2500 of 11923) 0:01:14 0:00:28
# Parsing XML files... ---- ----------------  21% (2522 of 11923) 0:01:14 0:00:28
# Parsing XML files... ---- ----------------  21% (2541 of 11923) 0:01:15 0:00:28
# Parsing XML files... ---- ----------------  22% (2574 of 11923) 0:01:14 0:00:28
# Parsing XML files... ---- ----------------  22% (2593 of 11923) 0:01:14 0:00:31
# Parsing XML files... ---- ----------------  22% (2610 of 11923) 0:01:37 0:00:31
# Parsing XML files... ---- ----------------  22% (2630 of 11923) 0:01:37 0:00:31
# Parsing XML files... ---- ----------------  22% (2652 of 11923) 0:01:37 0:00:31
# Parsing XML files... ---- ----------------  23% (2703 of 11923) 0:01:39 0:00:32
# Parsing XML files... ---- ----------------  23% (2733 of 11923) 0:01:29 0:00:32
# Parsing XML files... ---- ----------------  23% (2757 of 11923) 0:01:31 0:00:33
# Parsing XML files... ---- ----------------  23% (2774 of 11923) 0:01:31 0:00:33
# Parsing XML files... ---- ----------------  23% (2790 of 11923) 0:01:32 0:00:33
# Parsing XML files... ---- ----------------  24% (2813 of 11923) 0:01:33 0:00:33
# Parsing XML files... ---- ----------------  24% (2835 of 11923) 0:01:33 0:00:33
# Parsing XML files... ----- ---------------  24% (2852 of 11923) 0:01:33 0:00:33
# Parsing XML files... ----- ---------------  24% (2873 of 11923) 0:01:33 0:00:33
# Parsing XML files... ----- ---------------  24% (2889 of 11923) 0:01:34 0:00:33
# Parsing XML files... ----- ---------------  24% (2918 of 11923) 0:01:34 0:00:34
# Parsing XML files... ----- ---------------  25% (2939 of 11923) 0:01:34 0:00:34
# Parsing XML files... ----- ---------------  25% (2968 of 11923) 0:01:34 0:00:34
# Parsing XML files... ----- ---------------  25% (3004 of 11923) 0:01:33 0:00:34
# Parsing XML files... ----- ---------------  25% (3027 of 11923) 0:01:33 0:00:34
# Parsing XML files... ----- ---------------  26% (3048 of 11923) 0:01:33 0:00:34
# Parsing XML files... ----- ---------------  26% (3065 of 11923) 0:01:33 0:00:34
# Parsing XML files... ----- ---------------  26% (3089 of 11923) 0:01:32 0:00:37
# Parsing XML files... ----- ---------------  26% (3102 of 11923) 0:01:57 0:00:37
# Parsing XML files... ----- ---------------  26% (3109 of 11923) 0:01:57 0:00:38
# Parsing XML files... ----- ---------------  26% (3144 of 11923) 0:01:57 0:00:38
# Parsing XML files... ----- ---------------  27% (3186 of 11923) 0:01:43 0:00:38
# Parsing XML files... ----- ---------------  27% (3210 of 11923) 0:01:43 0:00:38
# Parsing XML files... ----- ---------------  27% (3232 of 11923) 0:01:43 0:00:38
# Parsing XML files... ----- ---------------  27% (3257 of 11923) 0:01:43 0:00:38
# Parsing XML files... ----- ---------------  27% (3275 of 11923) 0:01:42 0:00:38
# Parsing XML files... ----- ---------------  28% (3311 of 11923) 0:01:42 0:00:39
# Parsing XML files... ----- ---------------  28% (3319 of 11923) 0:01:42 0:00:39
# Parsing XML files... ----- ---------------  28% (3347 of 11923) 0:01:42 0:00:39
# Parsing XML files... ----- ---------------  28% (3364 of 11923) 0:01:43 0:00:39
# Parsing XML files... ----- ---------------  28% (3378 of 11923) 0:01:43 0:00:39
# Parsing XML files... ----- ---------------  28% (3389 of 11923) 0:01:43 0:00:39
# Parsing XML files... ------ --------------  29% (3409 of 11923) 0:01:44 0:00:40
# Parsing XML files... ------ --------------  29% (3425 of 11923) 0:01:44 0:00:40
# Parsing XML files... ------ --------------  29% (3445 of 11923) 0:01:44 0:00:40
# Parsing XML files... ------ --------------  29% (3477 of 11923) 0:01:43 0:00:40
# Parsing XML files... ------ --------------  29% (3508 of 11923) 0:01:44 0:00:40
# Parsing XML files... ------ --------------  30% (3523 of 11923) 0:01:44 0:00:41
# Parsing XML files... ------ --------------  30% (3548 of 11923) 0:01:45 0:00:41
# Parsing XML files... ------ --------------  30% (3569 of 11923) 0:01:45 0:00:41
# Parsing XML files... ------ --------------  30% (3592 of 11923) 0:01:45 0:00:41
# Parsing XML files... ------ --------------  30% (3619 of 11923) 0:01:24 0:00:41
# Parsing XML files... ------ --------------  31% (3638 of 11923) 0:01:24 0:00:41
# Parsing XML files... ------ --------------  31% (3667 of 11923) 0:01:22 0:00:42
# Parsing XML files... ------ --------------  31% (3693 of 11923) 0:01:22 0:00:42
# Parsing XML files... ------ --------------  31% (3721 of 11923) 0:01:22 0:00:42
# Parsing XML files... ------ --------------  31% (3729 of 11923) 0:01:21 0:00:46
# Parsing XML files... ------ --------------  32% (3762 of 11923) 0:01:48 0:00:46
# Parsing XML files... ------ --------------  32% (3783 of 11923) 0:01:47 0:00:46
# Parsing XML files... ------ --------------  32% (3806 of 11923) 0:01:47 0:00:46
# Parsing XML files... ------ --------------  32% (3837 of 11923) 0:01:46 0:00:46
# Parsing XML files... ------ --------------  33% (3884 of 11923) 0:01:44 0:00:46
# Parsing XML files... ------ --------------  33% (3912 of 11923) 0:01:44 0:00:46
# Parsing XML files... ------ --------------  33% (3935 of 11923) 0:01:43 0:00:47
# Parsing XML files... ------ --------------  33% (3962 of 11923) 0:01:43 0:00:47
# Parsing XML files... ------- -------------  33% (3976 of 11923) 0:01:43 0:00:47
# Parsing XML files... ------- -------------  34% (4002 of 11923) 0:01:43 0:00:47
# Parsing XML files... ------- -------------  34% (4026 of 11923) 0:01:42 0:00:47
# Parsing XML files... ------- -------------  34% (4045 of 11923) 0:01:42 0:00:47
# Parsing XML files... ------- -------------  34% (4061 of 11923) 0:01:42 0:00:47
# Parsing XML files... ------- -------------  34% (4079 of 11923) 0:01:42 0:00:47
# Parsing XML files... ------- -------------  34% (4100 of 11923) 0:01:20 0:00:48
# Parsing XML files... ------- -------------  35% (4116 of 11923) 0:01:20 0:00:48
# Parsing XML files... ------- -------------  35% (4130 of 11923) 0:01:20 0:00:48
# Parsing XML files... ------- -------------  35% (4149 of 11923) 0:01:20 0:00:48
# Parsing XML files... ------- -------------  35% (4165 of 11923) 0:01:19 0:00:48
# Parsing XML files... ------- -------------  35% (4179 of 11923) 0:01:21 0:00:48
# Parsing XML files... ------- -------------  35% (4200 of 11923) 0:01:21 0:00:48
# Parsing XML files... ------- -------------  35% (4213 of 11923) 0:01:20 0:00:48
# Parsing XML files... ------- -------------  36% (4237 of 11923) 0:01:20 0:00:49
# Parsing XML files... ------- -------------  36% (4256 of 11923) 0:01:20 0:00:49
# Parsing XML files... ------- -------------  36% (4285 of 11923) 0:01:20 0:00:49
# Parsing XML files... ------- -------------  36% (4300 of 11923) 0:01:20 0:00:49
# Parsing XML files... ------- -------------  36% (4317 of 11923) 0:01:19 0:00:49
# Parsing XML files... ------- -------------  36% (4337 of 11923) 0:01:18 0:00:49
# Parsing XML files... ------- -------------  37% (4384 of 11923) 0:01:16 0:00:49
# Parsing XML files... ------- -------------  37% (4417 of 11923) 0:01:14 0:00:50
# Parsing XML files... ------- -------------  37% (4446 of 11923) 0:01:13 0:00:50
# Parsing XML files... ------- -------------  38% (4472 of 11923) 0:01:13 0:00:50
# Parsing XML files... ------- -------------  38% (4504 of 11923) 0:01:12 0:00:50
# Parsing XML files... ------- -------------  38% (4521 of 11923) 0:01:11 0:00:50
# Parsing XML files... ------- -------------  38% (4542 of 11923) 0:01:11 0:00:50
# Parsing XML files... -------- ------------  38% (4559 of 11923) 0:01:10 0:00:50
# Parsing XML files... -------- ------------  38% (4569 of 11923) 0:01:10 0:00:51
# Parsing XML files... -------- ------------  38% (4581 of 11923) 0:01:11 0:00:51
# Parsing XML files... -------- ------------  39% (4596 of 11923) 0:01:42 0:00:55
# Parsing XML files... -------- ------------  39% (4602 of 11923) 0:01:42 0:00:55
# Parsing XML files... -------- ------------  39% (4631 of 11923) 0:01:42 0:00:55
# Parsing XML files... -------- ------------  39% (4648 of 11923) 0:01:42 0:00:55
# Parsing XML files... -------- ------------  39% (4670 of 11923) 0:01:41 0:00:56
# Parsing XML files... -------- ------------  39% (4684 of 11923) 0:01:41 0:00:56
# Parsing XML files... -------- ------------  39% (4702 of 11923) 0:01:41 0:00:56
# Parsing XML files... -------- ------------  40% (4725 of 11923) 0:01:41 0:00:56
# Parsing XML files... -------- ------------  40% (4740 of 11923) 0:01:16 0:00:56
# Parsing XML files... -------- ------------  40% (4762 of 11923) 0:01:16 0:00:56
# Parsing XML files... -------- ------------  40% (4777 of 11923) 0:01:17 0:00:56
# Parsing XML files... -------- ------------  40% (4787 of 11923) 0:01:17 0:00:57
# Parsing XML files... -------- ------------  40% (4803 of 11923) 0:01:17 0:00:57
# Parsing XML files... -------- ------------  40% (4823 of 11923) 0:01:17 0:00:57
# Parsing XML files... -------- ------------  41% (4844 of 11923) 0:01:17 0:00:57
# Parsing XML files... -------- ------------  41% (4858 of 11923) 0:01:17 0:00:57
# Parsing XML files... -------- ------------  41% (4878 of 11923) 0:01:18 0:00:57
# Parsing XML files... -------- ------------  41% (4903 of 11923) 0:01:18 0:00:57
# Parsing XML files... -------- ------------  41% (4916 of 11923) 0:01:18 0:00:58
# Parsing XML files... -------- ------------  41% (4941 of 11923) 0:01:18 0:00:58
# Parsing XML files... -------- ------------  42% (4971 of 11923) 0:01:17 0:00:58
# Parsing XML files... -------- ------------  42% (4987 of 11923) 0:01:17 0:00:58
# Parsing XML files... -------- ------------  42% (5004 of 11923) 0:01:18 0:00:58
# Parsing XML files... -------- ------------  42% (5025 of 11923) 0:01:18 0:00:58
# Parsing XML files... -------- ------------  42% (5039 of 11923) 0:01:19 0:00:58
# Parsing XML files... -------- ------------  42% (5049 of 11923) 0:01:18 0:00:59
# Parsing XML files... -------- ------------  42% (5056 of 11923) 0:01:19 0:00:59
# Parsing XML files... -------- ------------  43% (5070 of 11923) 0:01:19 0:00:59
# Parsing XML files... -------- ------------  43% (5081 of 11923) 0:01:19 0:00:59
# Parsing XML files... -------- ------------  43% (5097 of 11923) 0:01:19 0:00:59
# Parsing XML files... --------- -----------  43% (5114 of 11923) 0:01:18 0:00:59
# Parsing XML files... --------- -----------  43% (5137 of 11923) 0:01:18 0:00:59
# Parsing XML files... --------- -----------  43% (5150 of 11923) 0:01:19 0:00:59
# Parsing XML files... --------- -----------  43% (5162 of 11923) 0:01:19 0:01:00
# Parsing XML files... --------- -----------  43% (5177 of 11923) 0:01:18 0:01:00
# Parsing XML files... --------- -----------  44% (5203 of 11923) 0:01:18 0:01:00
# Parsing XML files... --------- -----------  44% (5221 of 11923) 0:01:18 0:01:00
# Parsing XML files... --------- -----------  44% (5241 of 11923) 0:01:17 0:01:00
# Parsing XML files... --------- -----------  44% (5255 of 11923) 0:01:17 0:01:00
# Parsing XML files... --------- -----------  44% (5271 of 11923) 0:01:18 0:01:00
# Parsing XML files... --------- -----------  44% (5289 of 11923) 0:01:18 0:01:01
# Parsing XML files... --------- -----------  45% (5324 of 11923) 0:01:18 0:01:01
# Parsing XML files... --------- -----------  45% (5341 of 11923) 0:01:18 0:01:01
# Parsing XML files... --------- -----------  45% (5360 of 11923) 0:01:18 0:01:01
# Parsing XML files... --------- -----------  45% (5379 of 11923) 0:01:19 0:01:01
# Parsing XML files... --------- -----------  45% (5391 of 11923) 0:01:19 0:01:06
# Parsing XML files... --------- -----------  45% (5405 of 11923) 0:01:51 0:01:06
# Parsing XML files... --------- -----------  45% (5407 of 11923) 0:01:52 0:01:07
# Parsing XML files... --------- -----------  46% (5429 of 11923) 0:01:53 0:01:07
# Parsing XML files... --------- -----------  46% (5456 of 11923) 0:01:52 0:01:07
# Parsing XML files... --------- -----------  46% (5481 of 11923) 0:01:52 0:01:07
# Parsing XML files... --------- -----------  46% (5497 of 11923) 0:01:53 0:01:07
# Parsing XML files... --------- -----------  46% (5507 of 11923) 0:01:53 0:01:08
# Parsing XML files... --------- -----------  46% (5524 of 11923) 0:01:53 0:01:08
# Parsing XML files... --------- -----------  47% (5547 of 11923) 0:01:53 0:01:08
# Parsing XML files... --------- -----------  47% (5560 of 11923) 0:01:53 0:01:08
# Parsing XML files... --------- -----------  47% (5576 of 11923) 0:01:52 0:01:08
# Parsing XML files... --------- -----------  47% (5596 of 11923) 0:01:24 0:01:08
# Parsing XML files... --------- -----------  47% (5617 of 11923) 0:01:24 0:01:08
# Parsing XML files... --------- -----------  47% (5624 of 11923) 0:01:24 0:01:09
# Parsing XML files... --------- -----------  47% (5650 of 11923) 0:01:24 0:01:09
# Parsing XML files... ---------- ----------  48% (5690 of 11923) 0:01:22 0:01:09
# Parsing XML files... ---------- ----------  48% (5718 of 11923) 0:01:21 0:01:09
# Parsing XML files... ---------- ----------  48% (5768 of 11923) 0:01:19 0:01:09
# Parsing XML files... ---------- ----------  49% (5809 of 11923) 0:01:16 0:01:09
# Parsing XML files... ---------- ----------  49% (5831 of 11923) 0:01:16 0:01:09
# Parsing XML files... ---------- ----------  49% (5854 of 11923) 0:01:15 0:01:09
# Parsing XML files... ---------- ----------  49% (5885 of 11923) 0:01:15 0:01:10
# Parsing XML files... ---------- ----------  50% (5914 of 11923) 0:01:13 0:01:10
# Parsing XML files... ---------- ----------  50% (5941 of 11923) 0:01:13 0:01:10
# Parsing XML files... ---------- ----------  50% (5964 of 11923) 0:01:12 0:01:10
# Parsing XML files... ---------- ----------  50% (5987 of 11923) 0:01:12 0:01:10
# Parsing XML files... ---------- ----------  50% (6006 of 11923) 0:01:12 0:01:10
# Parsing XML files... ---------- ----------  51% (6031 of 11923) 0:01:11 0:01:10
# Parsing XML files... ---------- ----------  51% (6053 of 11923) 0:01:10 0:01:10
# Parsing XML files... ---------- ----------  51% (6084 of 11923) 0:01:08 0:01:11
# Parsing XML files... ---------- ----------  51% (6107 of 11923) 0:01:08 0:01:11
# Parsing XML files... ---------- ----------  51% (6125 of 11923) 0:01:07 0:01:11
# Parsing XML files... ---------- ----------  52% (6145 of 11923) 0:01:07 0:01:11
# Parsing XML files... ---------- ----------  52% (6168 of 11923) 0:01:06 0:01:11
# Parsing XML files... ---------- ----------  52% (6195 of 11923) 0:01:05 0:01:11
# Parsing XML files... ---------- ----------  52% (6223 of 11923) 0:01:05 0:01:11
# Parsing XML files... ----------- ---------  52% (6258 of 11923) 0:01:04 0:01:11
# Parsing XML files... ----------- ---------  53% (6305 of 11923) 0:01:02 0:01:12
# Parsing XML files... ----------- ---------  53% (6325 of 11923) 0:01:01 0:01:12
# Parsing XML files... ----------- ---------  53% (6373 of 11923) 0:01:00 0:01:12
# Parsing XML files... ----------- ---------  54% (6399 of 11923) 0:00:32 0:01:12
# Parsing XML files... ----------- ---------  54% (6423 of 11923) 0:00:30 0:01:12
# Parsing XML files... ----------- ---------  54% (6475 of 11923) 0:00:29 0:01:12
# Parsing XML files... ----------- ---------  55% (6501 of 11923) 0:00:28 0:01:13
# Parsing XML files... ----------- ---------  55% (6523 of 11923) 0:00:27 0:01:13
# Parsing XML files... ----------- ---------  55% (6556 of 11923) 0:00:26 0:01:13
# Parsing XML files... ----------- ---------  55% (6571 of 11923) 0:00:26 0:01:13
# Parsing XML files... ----------- ---------  55% (6591 of 11923) 0:00:26 0:01:13
# Parsing XML files... ----------- ---------  55% (6606 of 11923) 0:00:26 0:01:13
# Parsing XML files... ----------- ---------  56% (6628 of 11923) 0:00:26 0:01:13
# Parsing XML files... ----------- ---------  56% (6645 of 11923) 0:00:26 0:01:13
# Parsing XML files... ----------- ---------  56% (6673 of 11923) 0:00:26 0:01:14
# Parsing XML files... ----------- ---------  56% (6682 of 11923) 0:00:26 0:01:14
# Parsing XML files... ----------- ---------  56% (6701 of 11923) 0:00:26 0:01:14
# Parsing XML files... ----------- ---------  56% (6719 of 11923) 0:00:27 0:01:14
# Parsing XML files... ----------- ---------  57% (6739 of 11923) 0:00:27 0:01:14
# Parsing XML files... ----------- ---------  57% (6772 of 11923) 0:00:28 0:01:14
# Parsing XML files... ----------- ---------  57% (6791 of 11923) 0:00:28 0:01:14
# Parsing XML files... ----------- ---------  57% (6805 of 11923) 0:00:28 0:01:15
# Parsing XML files... ------------ --------  57% (6822 of 11923) 0:00:28 0:01:15
# Parsing XML files... ------------ --------  57% (6842 of 11923) 0:00:28 0:01:15
# Parsing XML files... ------------ --------  58% (6871 of 11923) 0:00:28 0:01:15
# Parsing XML files... ------------ --------  58% (6884 of 11923) 0:00:59 0:01:21
# Parsing XML files... ------------ --------  58% (6889 of 11923) 0:00:59 0:01:21
# Parsing XML files... ------------ --------  58% (6915 of 11923) 0:01:00 0:01:22
# Parsing XML files... ------------ --------  58% (6949 of 11923) 0:01:00 0:01:22
# Parsing XML files... ------------ --------  58% (6970 of 11923) 0:01:00 0:01:22
# Parsing XML files... ------------ --------  59% (6986 of 11923) 0:01:00 0:01:22
# Parsing XML files... ------------ --------  59% (7009 of 11923) 0:01:00 0:01:22
# Parsing XML files... ------------ --------  59% (7037 of 11923) 0:00:59 0:01:22
# Parsing XML files... ------------ --------  59% (7060 of 11923) 0:00:59 0:01:22
# Parsing XML files... ------------ --------  59% (7089 of 11923) 0:00:58 0:01:23
# Parsing XML files... ------------ --------  60% (7109 of 11923) 0:00:58 0:01:23
# Parsing XML files... ------------ --------  60% (7116 of 11923) 0:00:59 0:01:23
# Parsing XML files... ------------ --------  60% (7133 of 11923) 0:00:59 0:01:23
# Parsing XML files... ------------ --------  60% (7158 of 11923) 0:00:58 0:01:23
# Parsing XML files... ------------ --------  60% (7186 of 11923) 0:00:58 0:01:23
# Parsing XML files... ------------ --------  60% (7208 of 11923) 0:00:58 0:01:23
# Parsing XML files... ------------ --------  61% (7229 of 11923) 0:00:58 0:01:24
# Parsing XML files... ------------ --------  61% (7242 of 11923) 0:00:59 0:01:24
# Parsing XML files... ------------ --------  61% (7257 of 11923) 0:00:59 0:01:24
# Parsing XML files... ------------ --------  61% (7276 of 11923) 0:00:59 0:01:24
# Parsing XML files... ------------ --------  61% (7307 of 11923) 0:00:58 0:01:24
# Parsing XML files... ------------ --------  62% (7336 of 11923) 0:00:58 0:01:24
# Parsing XML files... ------------ --------  62% (7375 of 11923) 0:00:57 0:01:24
# Parsing XML files... ------------- -------  62% (7405 of 11923) 0:00:57 0:01:25
# Parsing XML files... ------------- -------  62% (7433 of 11923) 0:00:57 0:01:25
# Parsing XML files... ------------- -------  63% (7460 of 11923) 0:00:57 0:01:25
# Parsing XML files... ------------- -------  63% (7478 of 11923) 0:00:57 0:01:25
# Parsing XML files... ------------- -------  63% (7498 of 11923) 0:00:57 0:01:25
# Parsing XML files... ------------- -------  63% (7511 of 11923) 0:00:57 0:01:25
# Parsing XML files... ------------- -------  63% (7537 of 11923) 0:00:57 0:01:26
# Parsing XML files... ------------- -------  63% (7556 of 11923) 0:00:57 0:01:26
# Parsing XML files... ------------- -------  63% (7563 of 11923) 0:00:58 0:01:26
# Parsing XML files... ------------- -------  63% (7569 of 11923) 0:00:58 0:01:26
# Parsing XML files... ------------- -------  64% (7582 of 11923) 0:00:58 0:01:26
# Parsing XML files... ------------- -------  64% (7600 of 11923) 0:00:58 0:01:26
# Parsing XML files... ------------- -------  64% (7629 of 11923) 0:00:57 0:01:27
# Parsing XML files... ------------- -------  64% (7654 of 11923) 0:00:57 0:01:27
# Parsing XML files... ------------- -------  64% (7665 of 11923) 0:00:57 0:01:27
# Parsing XML files... ------------- -------  64% (7677 of 11923) 0:00:57 0:01:27
# Parsing XML files... ------------- -------  64% (7685 of 11923) 0:00:57 0:01:27
# Parsing XML files... ------------- -------  65% (7702 of 11923) 0:00:57 0:01:27
# Parsing XML files... ------------- -------  65% (7728 of 11923) 0:00:57 0:01:27
# Parsing XML files... ------------- -------  65% (7754 of 11923) 0:00:56 0:01:28
# Parsing XML files... ------------- -------  65% (7782 of 11923) 0:00:56 0:01:28
# Parsing XML files... ------------- -------  66% (7812 of 11923) 0:00:55 0:01:28
# Parsing XML files... ------------- -------  66% (7827 of 11923) 0:00:55 0:01:28
# Parsing XML files... ------------- -------  66% (7855 of 11923) 0:00:54 0:01:28
# Parsing XML files... ------------- -------  66% (7889 of 11923) 0:00:29 0:01:28
# Parsing XML files... ------------- -------  66% (7926 of 11923) 0:00:28 0:01:29
# Parsing XML files... ------------- -------  67% (7945 of 11923) 0:00:29 0:01:29
# Parsing XML files... -------------- ------  67% (7969 of 11923) 0:00:28 0:01:29
# Parsing XML files... -------------- ------  67% (7995 of 11923) 0:00:27 0:01:29
# Parsing XML files... -------------- ------  67% (8014 of 11923) 0:00:27 0:01:29
# Parsing XML files... -------------- ------  67% (8031 of 11923) 0:00:27 0:01:29
# Parsing XML files... -------------- ------  68% (8060 of 11923) 0:00:27 0:01:29
# Parsing XML files... -------------- ------  68% (8090 of 11923) 0:00:27 0:01:29
# Parsing XML files... -------------- ------  68% (8124 of 11923) 0:00:26 0:01:30
# Parsing XML files... -------------- ------  68% (8142 of 11923) 0:00:26 0:01:30
# Parsing XML files... -------------- ------  68% (8166 of 11923) 0:00:26 0:01:30
# Parsing XML files... -------------- ------  69% (8192 of 11923) 0:00:25 0:01:30
# Parsing XML files... -------------- ------  69% (8230 of 11923) 0:00:25 0:01:30
# Parsing XML files... -------------- ------  69% (8246 of 11923) 0:00:25 0:01:30
# Parsing XML files... -------------- ------  69% (8262 of 11923) 0:00:25 0:01:31
# Parsing XML files... -------------- ------  69% (8269 of 11923) 0:00:25 0:01:31
# Parsing XML files... -------------- ------  69% (8279 of 11923) 0:00:25 0:01:31
# Parsing XML files... -------------- ------  70% (8294 of 11923) 0:00:25 0:01:31
# Parsing XML files... -------------- ------  70% (8315 of 11923) 0:00:25 0:01:31
# Parsing XML files... -------------- ------  70% (8368 of 11923) 0:00:26 0:01:32
# Parsing XML files... -------------- ------  70% (8382 of 11923) 0:00:26 0:01:32
# Parsing XML files... -------------- ------  71% (8409 of 11923) 0:00:26 0:01:32
# Parsing XML files... -------------- ------  71% (8426 of 11923) 0:00:55 0:01:40
# Parsing XML files... -------------- ------  71% (8478 of 11923) 0:00:54 0:01:41
# Parsing XML files... -------------- ------  71% (8508 of 11923) 0:00:53 0:01:41
# Parsing XML files... --------------- -----  72% (8527 of 11923) 0:00:53 0:01:41
# Parsing XML files... --------------- -----  72% (8547 of 11923) 0:00:52 0:01:41
# Parsing XML files... --------------- -----  72% (8585 of 11923) 0:00:50 0:01:41
# Parsing XML files... --------------- -----  72% (8609 of 11923) 0:00:50 0:01:41
# Parsing XML files... --------------- -----  72% (8625 of 11923) 0:00:50 0:01:42
# Parsing XML files... --------------- -----  73% (8661 of 11923) 0:00:49 0:01:42
# Parsing XML files... --------------- -----  73% (8693 of 11923) 0:00:48 0:01:42
# Parsing XML files... --------------- -----  73% (8720 of 11923) 0:00:48 0:01:42
# Parsing XML files... --------------- -----  74% (8766 of 11923) 0:00:48 0:01:43
# Parsing XML files... --------------- -----  74% (8783 of 11923) 0:00:48 0:01:43
# Parsing XML files... --------------- -----  74% (8814 of 11923) 0:00:47 0:01:43
# Parsing XML files... --------------- -----  74% (8867 of 11923) 0:00:46 0:01:43
# Parsing XML files... --------------- -----  75% (8885 of 11923) 0:00:46 0:01:43
# Parsing XML files... --------------- -----  75% (8914 of 11923) 0:00:46 0:01:43
# Parsing XML files... --------------- -----  75% (8927 of 11923) 0:00:45 0:01:44
# Parsing XML files... --------------- -----  75% (8943 of 11923) 0:00:45 0:01:44
# Parsing XML files... --------------- -----  75% (8959 of 11923) 0:00:45 0:01:44
# Parsing XML files... --------------- -----  75% (8990 of 11923) 0:00:45 0:01:44
# Parsing XML files... --------------- -----  76% (9040 of 11923) 0:00:44 0:01:44
# Parsing XML files... --------------- -----  76% (9079 of 11923) 0:00:43 0:01:45
# Parsing XML files... ---------------- ----  76% (9099 of 11923) 0:00:43 0:01:45
# Parsing XML files... ---------------- ----  77% (9170 of 11923) 0:00:42 0:01:45
# Parsing XML files... ---------------- ----  77% (9188 of 11923) 0:00:42 0:01:45
# Parsing XML files... ---------------- ----  77% (9208 of 11923) 0:00:42 0:01:45
# Parsing XML files... ---------------- ----  77% (9237 of 11923) 0:00:42 0:01:46
# Parsing XML files... ---------------- ----  78% (9266 of 11923) 0:00:41 0:01:46
# Parsing XML files... ---------------- ----  78% (9281 of 11923) 0:00:41 0:01:46
# Parsing XML files... ---------------- ----  78% (9289 of 11923) 0:00:41 0:01:46
# Parsing XML files... ---------------- ----  78% (9295 of 11923) 0:00:41 0:01:46
# Parsing XML files... ---------------- ----  78% (9309 of 11923) 0:00:40 0:01:46
# Parsing XML files... ---------------- ----  78% (9318 of 11923) 0:00:40 0:01:47
# Parsing XML files... ---------------- ----  79% (9370 of 11923) 0:00:40 0:01:47
# Parsing XML files... ---------------- ----  79% (9447 of 11923) 0:00:19 0:01:48
# Parsing XML files... ---------------- ----  79% (9463 of 11923) 0:00:19 0:01:48
# Parsing XML files... ---------------- ----  80% (9480 of 11923) 0:00:19 0:01:48
# Parsing XML files... ---------------- ----  80% (9555 of 11923) 0:00:19 0:01:49
# Parsing XML files... ---------------- ----  81% (9599 of 11923) 0:00:19 0:01:49
# Parsing XML files... ---------------- ----  81% (9619 of 11923) 0:00:19 0:01:50
# Parsing XML files... ---------------- ----  81% (9641 of 11923) 0:00:19 0:01:50
# Parsing XML files... ----------------- ---  81% (9659 of 11923) 0:00:19 0:01:50
# Parsing XML files... ----------------- ---  81% (9711 of 11923) 0:00:18 0:01:50
# Parsing XML files... ----------------- ---  82% (9749 of 11923) 0:00:18 0:01:51
# Parsing XML files... ----------------- ---  82% (9752 of 11923) 0:00:19 0:01:51
# Parsing XML files... ----------------- ---  82% (9764 of 11923) 0:00:19 0:01:51
# Parsing XML files... ----------------- ---  82% (9785 of 11923) 0:00:18 0:01:51
# Parsing XML files... ----------------- ---  82% (9824 of 11923) 0:00:18 0:01:51
# Parsing XML files... ----------------- ---  83% (9849 of 11923) 0:00:18 0:01:52
# Parsing XML files... ----------------- ---  83% (9864 of 11923) 0:00:18 0:01:52
# Parsing XML files... ----------------- ---  83% (9878 of 11923) 0:00:18 0:01:52
# Parsing XML files... ----------------- ---  83% (9891 of 11923) 0:00:18 0:01:52
# Parsing XML files... ----------------- ---  83% (9938 of 11923) 0:00:17 0:01:52
# Parsing XML files... ----------------- ---  83% (9947 of 11923) 0:00:18 0:01:52
# Parsing XML files... ----------------- ---  84% (9960 of 11923) 0:00:18 0:01:52
# Parsing XML files... ----------------- ---  84% (9970 of 11923) 0:00:18 0:01:53
# Parsing XML files... ----------------- ---  84% (9993 of 11923) 0:00:17 0:01:53
# Parsing XML files... ---------------- ---  84% (10019 of 11923) 0:00:17 0:01:53
# Parsing XML files... ---------------- ---  84% (10045 of 11923) 0:00:17 0:01:53
# Parsing XML files... ---------------- ---  84% (10054 of 11923) 0:00:17 0:01:53
# Parsing XML files... ---------------- ---  84% (10074 of 11923) 0:00:17 0:01:53
# Parsing XML files... ---------------- ---  85% (10091 of 11923) 0:00:17 0:01:54
# Parsing XML files... ---------------- ---  85% (10099 of 11923) 0:00:17 0:01:54
# Parsing XML files... ---------------- ---  85% (10122 of 11923) 0:00:17 0:01:54
# Parsing XML files... ----------------- --  85% (10143 of 11923) 0:00:17 0:01:54
# Parsing XML files... ----------------- --  85% (10168 of 11923) 0:00:17 0:01:54
# Parsing XML files... ----------------- --  85% (10184 of 11923) 0:00:17 0:01:55
# Parsing XML files... ----------------- --  86% (10200 of 11923) 0:00:17 0:01:55
# Parsing XML files... ----------------- --  86% (10215 of 11923) 0:00:16 0:01:55
# Parsing XML files... ----------------- --  86% (10222 of 11923) 0:00:16 0:01:55
# Parsing XML files... ----------------- --  86% (10233 of 11923) 0:00:16 0:01:55
# Parsing XML files... ----------------- --  86% (10245 of 11923) 0:00:17 0:01:55
# Parsing XML files... ----------------- --  86% (10258 of 11923) 0:00:17 0:01:56
# Parsing XML files... ----------------- --  86% (10306 of 11923) 0:00:16 0:01:56
# Parsing XML files... ----------------- --  87% (10327 of 11923) 0:00:15 0:01:56
# Parsing XML files... ----------------- --  87% (10342 of 11923) 0:00:16 0:01:56
# Parsing XML files... ----------------- --  87% (10381 of 11923) 0:00:15 0:01:57
# Parsing XML files... ----------------- --  87% (10381 of 11923) 0:00:15 0:01:57
# Parsing XML files... ----------------- --  88% (10448 of 11923) 0:00:14 0:01:57
# Parsing XML files... ----------------- --  88% (10463 of 11923) 0:00:14 0:01:57
# Parsing XML files... ----------------- --  88% (10474 of 11923) 0:00:14 0:01:57
# Parsing XML files... ----------------- --  88% (10486 of 11923) 0:00:13 0:01:58
# Parsing XML files... ----------------- --  88% (10508 of 11923) 0:00:13 0:01:58
# Parsing XML files... ----------------- --  88% (10536 of 11923) 0:00:13 0:01:58
# Parsing XML files... ----------------- --  88% (10546 of 11923) 0:00:13 0:01:58
# Parsing XML files... ----------------- --  88% (10550 of 11923) 0:00:13 0:01:58
# Parsing XML files... ----------------- --  89% (10558 of 11923) 0:00:13 0:01:58
# Parsing XML files... ----------------- --  89% (10562 of 11923) 0:00:13 0:02:08
# Parsing XML files... ----------------- --  89% (10577 of 11923) 0:00:26 0:02:08
# Parsing XML files... ----------------- --  89% (10597 of 11923) 0:00:26 0:02:09
# Parsing XML files... ----------------- --  89% (10613 of 11923) 0:00:26 0:02:09
# Parsing XML files... ----------------- --  89% (10669 of 11923) 0:00:25 0:02:09
# Parsing XML files... ----------------- --  90% (10695 of 11923) 0:00:24 0:02:09
# Parsing XML files... ----------------- --  90% (10714 of 11923) 0:00:24 0:02:10
# Parsing XML files... ------------------ -  90% (10746 of 11923) 0:00:23 0:02:10
# Parsing XML files... ------------------ -  90% (10785 of 11923) 0:00:22 0:02:10
# Parsing XML files... ------------------ -  91% (10801 of 11923) 0:00:21 0:02:10
# Parsing XML files... ------------------ -  91% (10826 of 11923) 0:00:21 0:02:10
# Parsing XML files... ------------------ -  91% (10852 of 11923) 0:00:21 0:02:10
# Parsing XML files... ------------------ -  91% (10870 of 11923) 0:00:20 0:02:10
# Parsing XML files... ------------------ -  91% (10890 of 11923) 0:00:20 0:02:11
# Parsing XML files... ------------------ -  92% (10923 of 11923) 0:00:19 0:02:11
# Parsing XML files... ------------------ -  92% (10946 of 11923) 0:00:19 0:02:11
# Parsing XML files... ------------------ -  92% (10974 of 11923) 0:00:18 0:02:11
# Parsing XML files... ------------------ -  92% (11009 of 11923) 0:00:17 0:02:11
# Parsing XML files... ------------------ -  92% (11028 of 11923) 0:00:17 0:02:11
# Parsing XML files... ------------------ -  93% (11076 of 11923) 0:00:16 0:02:12
# Parsing XML files... ------------------ -  93% (11104 of 11923) 0:00:15 0:02:12
# Parsing XML files... ------------------ -  93% (11135 of 11923) 0:00:15 0:02:12
# Parsing XML files... ------------------ -  94% (11163 of 11923) 0:00:14 0:02:12
# Parsing XML files... ------------------ -  94% (11169 of 11923) 0:00:14 0:02:12
# Parsing XML files... ------------------ -  94% (11177 of 11923) 0:00:14 0:02:12
# Parsing XML files... ------------------ -  94% (11202 of 11923) 0:00:13 0:02:13
# Parsing XML files... ------------------ -  94% (11227 of 11923) 0:00:13 0:02:13
# Parsing XML files... ------------------ -  95% (11270 of 11923) 0:00:12 0:02:13
# Parsing XML files... ------------------ -  95% (11292 of 11923) 0:00:11 0:02:13
# Parsing XML files... ------------------ -  95% (11314 of 11923) 0:00:11 0:02:13
# Parsing XML files... -------------------   95% (11337 of 11923) 0:00:10 0:02:13
# Parsing XML files... -------------------   95% (11356 of 11923) 0:00:10 0:02:14
# Parsing XML files... -------------------   96% (11392 of 11923) 0:00:09 0:02:14
# Parsing XML files... -------------------   96% (11427 of 11923) 0:00:09 0:02:14
# Parsing XML files... -------------------   96% (11444 of 11923) 0:00:09 0:02:14
# Parsing XML files... -------------------   96% (11470 of 11923) 0:00:08 0:02:14
# Parsing XML files... -------------------   96% (11496 of 11923) 0:00:08 0:02:14
# Parsing XML files... -------------------   96% (11503 of 11923) 0:00:07 0:02:14
# Parsing XML files... -------------------   97% (11522 of 11923) 0:00:07 0:02:14
# Parsing XML files... -------------------   97% (11551 of 11923) 0:00:07 0:02:15
# Parsing XML files... -------------------   97% (11573 of 11923) 0:00:03 0:02:15
# Parsing XML files... -------------------   97% (11599 of 11923) 0:00:02 0:02:15
# Parsing XML files... -------------------   97% (11623 of 11923) 0:00:02 0:02:15
# Parsing XML files... -------------------   98% (11659 of 11923) 0:00:02 0:02:15
# Parsing XML files... -------------------   98% (11679 of 11923) 0:00:02 0:02:15
# Parsing XML files... -------------------   98% (11714 of 11923) 0:00:02 0:02:16
# Parsing XML files... -------------------   98% (11732 of 11923) 0:00:02 0:02:16
# Parsing XML files... -------------------   99% (11776 of 11923) 0:00:01 0:02:16
# Parsing XML files... -------------------   99% (11795 of 11923) 0:00:01 0:02:16
# Parsing XML files... -------------------   99% (11833 of 11923) 0:00:01 0:02:16
# Parsing XML files... -------------------   99% (11846 of 11923) 0:00:01 0:02:16
# Parsing XML files... -------------------  100% (11869 of 11923) 0:00:01 0:02:17
# Parsing XML files... -------------------  100% (11887 of 11923) 0:00:01 0:02:17
# Parsing XML files... -------------------  100% (11907 of 11923) 0:00:01 0:02:17
# Parsing XML files... -------------------  100% (11922 of 11923) 0:00:01 0:02:17
# Parsing XML files... -------------------  100% (11922 of 11923) 0:00:01 0:02:17
# Parsing XML files... -------------------  100% (11922 of 11923) 0:00:01 0:02:17
# Parsing XML files... -------------------  100% (11922 of 11923) 0:00:01 0:02:17
# Parsing XML files... -------------------  100% (11922 of 11923) 0:00:01 0:02:17
# Parsing XML files... -------------------- 100% (11923 of 11923) 0:00:00 0:02:17
# Parsing XML files... -------------------- 100% (11923 of 11923) 0:00:00 0:02:17
# Parsing XML files... -------------------- 100% (11923 of 11923) 0:00:00 0:02:17
# Parsing XML files... -------------------- 100% (11923 of 11923) 0:00:00 0:02:17
# Parsing XML files... -------------------- 100% (11923 of 11923) 0:00:00 0:02:17
# Parsing XML files... -------------------- 100% (11923 of 11923) 0:00:00 0:02:17
#
# ⚠️ Failed to parse 2 XML file(s) out of 11923.
# Failed files:
#   - C:\Users\angel\.thermoml\extracted_xml\10.1016\j.fluid.2018.07.020.xml
#   - C:\Users\angel\.thermoml\extracted_xml\10.1016\j.fluid.2018.07.021.xml
# Main data saved to: thermoml_data.csv
# Properties data saved to: thermoml_properties.csv
# Compounds data saved to: thermoml_compounds.csv
# DataFrame construction and saving complete.
# Default schema not found at C:\Users\angel\.ai-navigator\micromamba\envs\cpu\Lib\site-packages\thermoml_fair\data\ThermoML.xsd. Please ensure it's correctly installed or set THERMOML_SCHEMA_PATH.
# [WARNING] Schema could not be loaded. If .parsed.pkl files are missing or outdated, parsing XML directly will fail.
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1016\j.fluid.2018.07.020.xml: 'utf-8' codec can't decode byte 0xe2 in position 10143: invalid continuation byte
# Traceback (most recent call last):
#   File "C:\Users\angel\.ai-navigator\micromamba\envs\cpu\Lib\site-packages\thermoml_fair\core\utils.py", line 66, in parse_one
#     return parse_thermoml_xml(file_path, xsd_path_or_obj=schema_for_parsing)
#   File "C:\Users\angel\.ai-navigator\micromamba\envs\cpu\Lib\site-packages\thermoml_fair\core\parser.py", line 52, in parse_thermoml_xml
#     data_dict = xmltodict.parse(f.read())
#                                 ~~~~~~^^
#   File "<frozen codecs>", line 325, in decode
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe2 in position 10143: invalid continuation byte
#
# Failed to parse XML file C:\Users\angel\.thermoml\extracted_xml\10.1016\j.fluid.2018.07.021.xml: 'utf-8' codec can't decode byte 0xe2 in position 8633: invalid continuation byte
# Traceback (most recent call last):
#   File "C:\Users\angel\.ai-navigator\micromamba\envs\cpu\Lib\site-packages\thermoml_fair\core\utils.py", line 66, in parse_one
#     return parse_thermoml_xml(file_path, xsd_path_or_obj=schema_for_parsing)
#   File "C:\Users\angel\.ai-navigator\micromamba\envs\cpu\Lib\site-packages\thermoml_fair\core\parser.py", line 52, in parse_thermoml_xml
#     data_dict = xmltodict.parse(f.read())
#                                 ~~~~~~^^
#   File "<frozen codecs>", line 325, in decode
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe2 in position 8633: invalid continuation byte
#
#
# [WARNING] 2 file(s) failed to parse and were skipped.
# Use --show-failed-files to see the list of failed files.

# %% [markdown]
# After running the command, you will have three CSV files in your root directory: `thermoml_data.csv`, `thermoml_compounds.csv`, and `thermoml_properties.csv`. Let's load them using pandas to see the contents.

# %%
import pandas as pd

# Load the main data file
data_df = pd.read_csv('thermoml_data.csv')
data_df.head()
# Out:
# C:\Users\angel\AppData\Local\Temp\ipykernel_40456\2834160900.py:4: DtypeWarning: Columns (0,6,69) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_df = pd.read_csv('thermoml_data.csv')
#   material_id      components thermoml_fair_version  \
# 0           1  1,2-ethanediol                1.0.14
# 1           1  1,2-ethanediol                1.0.14
# 2           1  1,2-ethanediol                1.0.14
# 3           1  1,2-ethanediol                1.0.14
# 4           1  1,2-ethanediol                1.0.14
#
#                       property   value   phase           method  uncertainty  \
# 0  Thermal conductivity, W/m/K  0.2496  Liquid  Hot disk method          NaN
# 1  Thermal conductivity, W/m/K  0.2518  Liquid  Hot disk method          NaN
# 2  Thermal conductivity, W/m/K  0.2539  Liquid  Hot disk method          NaN
# 3  Thermal conductivity, W/m/K  0.2561  Liquid  Hot disk method          NaN
# 4  Thermal conductivity, W/m/K  0.2580  Liquid  Hot disk method          NaN
#
#                                          source_file  \
# 0  C:\Users\angel\.thermoml\extracted_xml\10.1007...
# 1  C:\Users\angel\.thermoml\extracted_xml\10.1007...
# 2  C:\Users\angel\.thermoml\extracted_xml\10.1007...
# 3  C:\Users\angel\.thermoml\extracted_xml\10.1007...
# 4  C:\Users\angel\.thermoml\extracted_xml\10.1007...
#
#                          doi  ...  Final mole fraction of solute  \
# 0  10.1007/s10765-005-5568-4  ...                            NaN
# 1  10.1007/s10765-005-5568-4  ...                            NaN
# 2  10.1007/s10765-005-5568-4  ...                            NaN
# 3  10.1007/s10765-005-5568-4  ...                            NaN
# 4  10.1007/s10765-005-5568-4  ...                            NaN
#
#   Amount concentration (molarity), mol/dm3_4  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Ratio of amount of solute to mass of solution, mol/kg_2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Ratio of amount of solute to mass of solution, mol/kg_3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Solvent: Ratio of amount of component to mass of solvent, mol/kg  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Lower temperature, K  Upper temperature, K  \
# 0                   NaN                   NaN
# 1                   NaN                   NaN
# 2                   NaN                   NaN
# 3                   NaN                   NaN
# 4                   NaN                   NaN
#
#    Amount concentration (molarity), mol/dm3_3  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Volume ratio of solute to solvent  formula
# 0                                NaN   C2H6O2
# 1                                NaN   C2H6O2
# 2                                NaN   C2H6O2
# 3                                NaN   C2H6O2
# 4                                NaN   C2H6O2
#
# [5 rows x 70 columns]

# %%
# Load the compounds file
compounds_df = pd.read_csv('thermoml_compounds.csv')
compounds_df.head()
# Out:
#    nOrgNum           sCommonName sFormulaMolec  \
# 0        1        1,2-ethanediol        C2H6O2
# 1        2     diethylene glycol       C4H10O3
# 2        3    triethylene glycol       C6H14O4
# 3        4  tetraethylene glycol       C8H18O5
# 4        1            butan-1-ol        C4H10O
#
#                                          source_file  sCASRegistryNum
# 0  C:\Users\angel\.thermoml\extracted_xml\10.1007...              NaN
# 1  C:\Users\angel\.thermoml\extracted_xml\10.1007...              NaN
# 2  C:\Users\angel\.thermoml\extracted_xml\10.1007...              NaN
# 3  C:\Users\angel\.thermoml\extracted_xml\10.1007...              NaN
# 4  C:\Users\angel\.thermoml\extracted_xml\10.1007...              NaN

# %%
# Load the properties file
properties_df = pd.read_csv('thermoml_properties.csv')
properties_df.head()
# Out:
#                             sPropName
# 0      2nd virial coefficient, m3/mol
# 1     3rd virial coefficient, m6/mol2
# 2              Amount density, mol/m3
# 3       Apparent molar volume, m3/mol
# 4  Binary diffusion coefficient, m2/s

# %% [markdown]
# ## Method 2: Using the Python API
#
# This method provides more flexibility and allows you to integrate the data extraction directly into your Python scripts or notebooks. The core function is `build_pandas_dataframe`.

# %%
from thermoml_fair.core.utils import build_pandas_dataframe
import os

# Define the path to the XML data files
data_dir = 'thermoml_fair/data/'

# %%
# Run the extraction
api_data_df, api_compounds_df, api_properties_df, failed_files = build_pandas_dataframe(data_dir)

print("Data extraction complete.")
# Out:
# c:\Users\angel\.ai-navigator\micromamba\envs\cpu\Lib\site-packages\rich\live.py:231: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ⚠️ Failed to parse 19 XML file(s) out of 19.
# Failed files:
#   - f
#   - t
#   - a
#   - /
#   - a
#   - r
#   - e
#   - /
#   - m
#   - t
#   - m
#   - h
#   - l
#   - r
#   - a
#   - _
#   - d
#   - o
#   - i
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Run the extraction
# ----> 2 api_data_df, api_compounds_df, api_properties_df, failed_files = build_pandas_dataframe(data_dir)
#       4 print("Data extraction complete.")
#
# ValueError: too many values to unpack (expected 4)

# %% [markdown]
# Now, let's inspect the DataFrames and the list of failed files.

# %%
print("Main Data:")
api_data_df.head()
# Out:
# Main Data:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 print("Main Data:")
# ----> 2 api_data_df.head()
#
# NameError: name 'api_data_df' is not defined

# %%
print("Compounds Data:")
api_compounds_df.head()

# %%
print("Properties Data:")
api_properties_df.head()

# %%
print("Failed Files:")
if failed_files:
    for file, error in failed_files:
        print(f"- {file}: {error}")
else:
    print("No files failed to parse.")

# %% [markdown]
# ## Bonus: Visualizing the Data
#
# Now that we have the data loaded into pandas DataFrames, we can create some visualizations to explore it. An interactive plot is a great way to showcase the richness of the dataset.
#
# Below, we will create a scatter plot of Density vs. Temperature. Each point will represent a measurement, colored by the compound's name. You can hover over any point to see more details, like the pressure and the source publication (DOI).

# %%
import plotly.express as px
import pandas as pd

# Ensure the data from the API call is available. 
# If you haven't run the API cells yet, please run them first.
if 'api_data_df' in locals() and 'api_compounds_df' in locals():
    # Merge the data and compounds dataframes to get compound names
    merged_df = pd.merge(api_data_df, api_compounds_df, on='nPureOrMixtureNum')

    # Filter for density measurements, which is a common and interesting property
    density_df = merged_df[merged_df['ePropName'] == 'Density, kg/m3'].copy()

    # Convert the property value column to numeric type for plotting
    density_df['ePropValue'] = pd.to_numeric(density_df['ePropValue'])

    if not density_df.empty:
        # Create the interactive scatter plot
        fig = px.scatter(
            density_df,
            x='Temperature, K',
            y='ePropValue',
            color='sIUPAC_name',  # Color points by the name of the compound
            hover_data=['Pressure, kPa', 'sDOI'],  # Show these details on hover
            title='Density of Compounds vs. Temperature'
        )

        # Update axis and legend labels for clarity
        fig.update_layout(
            yaxis_title="Density, kg/m3",
            xaxis_title="Temperature, K",
            legend_title="Compound"
        )

        fig.show()
    else:
        print("No density data found to plot.")
else:
    print("Please run the Python API cells above to load the data before creating the plot.")

# %%
## Method 1: Using the Command-Line Interface (CLI)

This is the simplest way to get started. The `thermoml-fair build-dataframe` command will scan the default data directory for XML files, process them, and save the results into the specified CSV files.

The `--show-failed-files` flag is recommended to get a list of any XML files that could not be parsed, which is useful for debugging.

# %%
# This command will create the CSV files in the same directory as this notebook.
# It will process all XML files found in the default cache directory (~/.thermoml/extracted_xml).
# !thermoml-fair build-dataframe --output-data-file thermoml_data.csv --output-compounds-file thermoml_compounds.csv --output-properties-file thermoml_properties.csv --show-failed-files

# %%
After running the cell above, you should see `thermoml_data.csv`, `thermoml_compounds.csv`, and `thermoml_properties.csv` in your project directory.

---

# %%
## Method 2: Calling the Python Function Directly

This method provides much more flexibility. By calling the `build_pandas_dataframe` function from the `thermoml_fair` library, you can load the data directly into memory as pandas DataFrames without first saving them to disk. This is ideal for interactive analysis and allows for more advanced configuration.

The steps are:
1.  Import the necessary functions.
2.  Locate the XML files in the `thermoml-fair` cache directory.
3.  Call the function to build the data bundle.
4.  Extract the DataFrames from the returned bundle.
5.  Optionally, save the DataFrames to files and inspect them.

# %%
import os
from pathlib import Path
import pandas as pd
from thermoml_fair.core.utils import build_pandas_dataframe, get_cache_dir
from thermoml_fair.scripts.cli import get_schema_object

# 1. Set up paths and parameters
# Get the default directory where the XML files are stored
# This is typically ~/.thermoml/extracted_xml
xml_directory = get_cache_dir()
output_data_file = 'thermoml_data_from_py.csv'
output_compounds_file = 'thermoml_compounds_from_py.csv'
output_properties_file = 'thermoml_properties_from_py.csv'

# Find all XML files in the directory
xml_files = list(xml_directory.rglob("*.xml"))
print(f"Found {len(xml_files)} XML files in {xml_directory}")

# Load the ThermoML schema for validation during parsing
schema_obj = get_schema_object()

if xml_files and schema_obj:
    print("Starting DataFrame construction...")
    # 2. Call the core function
    # This will parse the XMLs (using cached .pkl files if available) and build the DataFrames
    data_bundle = build_pandas_dataframe(
        xml_files=[str(f) for f in xml_files],
        xsd_path_or_obj=schema_obj,
        normalize_alloys=True, # Optional: Set to True if you need normalized formulas for alloys
        max_workers=None # Optional: Uses all available CPU cores by default
    )

    # 3. Extract the results
    df_data = data_bundle.get('data')
    df_compounds = data_bundle.get('compounds')
    df_properties = data_bundle.get('properties')
    failed_files = data_bundle.get('failed_files', [])

    # 4. Save the DataFrames to CSV files
    if df_data is not None and not df_data.empty:
        df_data.to_csv(output_data_file, index=False)
        print(f"Successfully saved {len(df_data)} records to {output_data_file}")

    if df_compounds is not None and not df_compounds.empty:
        df_compounds.to_csv(output_compounds_file, index=False)
        print(f"Successfully saved {len(df_compounds)} unique compounds to {output_compounds_file}")
        
    if df_properties is not None and not df_properties.empty:
        df_properties.to_csv(output_properties_file, index=False)
        print(f"Successfully saved {len(df_properties)} unique properties to {output_properties_file}")

    # 5. Report any failures
    if failed_files:
        print(f"\n[WARNING] {len(failed_files)} file(s) failed to parse and were skipped.")
        print("Failed files:")
        for f in failed_files[:10]: # Print the first 10 failed files
            print(f"  - {Path(f).name}")
        if len(failed_files) > 10:
            print(f"  ... and {len(failed_files) - 10} more.")
    
    print("\nDataFrame construction complete.")
    
    # You can now work with the DataFrame directly
    if df_data is not None:
        print("\n**Preview of the main data:**")
        display(df_data.head())

else:
    if not xml_files:
        print("No XML files found. Please run 'thermoml-fair update-archive' first.")
    if not schema_obj:
        print("Could not load the ThermoML schema. Please ensure the package is installed correctly.")
# Out:
# Found 0 XML files in C:\Users\angel\.thermoml\thermoml_cache
# No XML files found. Please run 'thermoml-fair update-archive' first.
